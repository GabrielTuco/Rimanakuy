# %%
# !python --version
# Out:
# Python 3.10.13

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 22E9-F6FB
#
#  Directorio de C:\Users\gabri\Rimanakuy
#
# 12/10/2023  10:43    <DIR>          .
# 12/10/2023  10:43    <DIR>          ..
# 12/10/2023  10:43    <DIR>          .ipynb_checkpoints
# 11/10/2023  16:11    <DIR>          helpers
# 11/10/2023  16:11    <DIR>          libs
# 11/10/2023  16:11    <DIR>          models
# 11/10/2023  16:11    <DIR>          modules
# 11/10/2023  16:11    <DIR>          mylogger
# 11/10/2023  16:49               301 requirements.txt
# 11/10/2023  16:11             1,188 sys_config.py
# 11/10/2023  16:11    <DIR>          tools
# 11/10/2023  17:41             2,374 Training.ipynb
#                3 archivos          3,863 bytes
#                9 dirs  523,649,871,872 bytes libres

# %%
# !pip install -r requirements.txt
# Out:
# Collecting typing~=3.6.6 (from -r requirements.txt (line 1))
#   Using cached typing-3.6.6-py3-none-any.whl (25 kB)
# Collecting torchtext~=0.4.0 (from -r requirements.txt (line 2))
#   Using cached torchtext-0.4.0-py3-none-any.whl (53 kB)
# Collecting torch (from -r requirements.txt (line 3))
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/fa/47/1a7daf04f40715fc1cdc6f1cc3200228a556d06c843e6ceb58883b745e1b/torch-2.1.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached torch-2.1.0-cp310-cp310-win_amd64.whl.metadata (24 kB)
# Collecting numpy (from -r requirements.txt (line 4))
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/cc/05/ef9fc04adda45d537619ea956bc33489f50a46badc949c4280d8309185ec/numpy-1.26.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached numpy-1.26.0-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting pyyaml (from -r requirements.txt (line 5))
#   Obtaining dependency information for pyyaml from https://files.pythonhosted.org/packages/24/97/9b59b43431f98d01806b288532da38099cc6f2fea0f3d712e21e269c0279/PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting sacrebleu~=1.4.2 (from -r requirements.txt (line 6))
#   Using cached sacrebleu-1.4.14-py3-none-any.whl (64 kB)
# Collecting matplotlib (from -r requirements.txt (line 7))
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/7a/94/a1615bac6706eb8a58fe08675b80a11b5463ef9591176dd3e57257495774/matplotlib-3.8.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached matplotlib-3.8.0-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting tqdm~=4.43.0 (from -r requirements.txt (line 8))
#   Using cached tqdm-4.43.0-py2.py3-none-any.whl (59 kB)
# Collecting transformers (from -r requirements.txt (line 9))
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/1a/d1/3bba59606141ae808017f6fde91453882f931957f125009417b87a281067/transformers-4.34.0-py3-none-any.whl.metadata
#   Using cached transformers-4.34.0-py3-none-any.whl.metadata (121 kB)
# Collecting pandas (from -r requirements.txt (line 10))
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ce/cd/a7c2cbffe2afff975349e60b14b63a448162145a7acac8ba12ddc2ed78a8/pandas-2.1.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached pandas-2.1.1-cp310-cp310-win_amd64.whl.metadata (18 kB)
# Collecting seaborn~=0.9.0 (from -r requirements.txt (line 11))
#   Using cached seaborn-0.9.1-py2.py3-none-any.whl (216 kB)
# Collecting tabulate~=0.8.3 (from -r requirements.txt (line 12))
#   Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting oyaml~=0.9 (from -r requirements.txt (line 13))
#   Using cached oyaml-0.9-py2.py3-none-any.whl (3.0 kB)
# Collecting umap~=0.1.1 (from -r requirements.txt (line 14))
#   Using cached umap-0.1.1-py3-none-any.whl
# Collecting scikit-learn (from -r requirements.txt (line 15))
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/59/ed/548f6f686845d386a727a51a3daa411d95fc599649a2d54705f6773ac259/scikit_learn-1.3.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached scikit_learn-1.3.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting sentencepiece (from -r requirements.txt (line 16))
#   Using cached sentencepiece-0.1.99-cp310-cp310-win_amd64.whl (977 kB)
# Collecting gensim (from -r requirements.txt (line 17))
#   Obtaining dependency information for gensim from https://files.pythonhosted.org/packages/ab/b0/d58dc405fd60ab546ca714321235dc2d455b2dc06bfb4fc1092940c749fc/gensim-4.3.2-cp310-cp310-win_amd64.whl.metadata
#   Using cached gensim-4.3.2-cp310-cp310-win_amd64.whl.metadata (8.5 kB)
# Collecting sacremoses~=0.0.35 (from -r requirements.txt (line 18))
#   Using cached sacremoses-0.0.53-py3-none-any.whl
# Collecting scipy (from -r requirements.txt (line 19))
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/3a/98/3041681b3a0fef0f59033861a05d846aa1d284b07b531ce35b1b97cc2e93/scipy-1.11.3-cp310-cp310-win_amd64.whl.metadata
#   Using cached scipy-1.11.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting glob2~=0.6 (from -r requirements.txt (line 20))
#   Using cached glob2-0.7-py2.py3-none-any.whl
# Collecting visdom~=0.1.8.9 (from -r requirements.txt (line 21))
#   Using cached visdom-0.1.8.9-py3-none-any.whl
# Collecting requests (from torchtext~=0.4.0->-r requirements.txt (line 2))
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from torchtext~=0.4.0->-r requirements.txt (line 2)) (1.16.0)
# Collecting filelock (from torch->-r requirements.txt (line 3))
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
#   Using cached filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from torch->-r requirements.txt (line 3)) (4.7.1)
# Collecting sympy (from torch->-r requirements.txt (line 3))
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch->-r requirements.txt (line 3))
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from torch->-r requirements.txt (line 3)) (3.1.2)
# Collecting fsspec (from torch->-r requirements.txt (line 3))
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/fe/d3/e1aa96437d944fbb9cc95d0316e25583886e9cd9e6adc07baad943524eda/fsspec-2023.9.2-py3-none-any.whl.metadata
#   Using cached fsspec-2023.9.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting portalocker (from sacrebleu~=1.4.2->-r requirements.txt (line 6))
#   Obtaining dependency information for portalocker from https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl.metadata
#   Using cached portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/55/14/0dc1884e3c04f9b073a47283f5d424926644250891db392a07c56f05e5c5/contourpy-1.1.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached contourpy-1.1.1-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/08/65/8c3c09f2fa948b0a4dabecccb5edaa1d97f0d564f00f638ba0a7c4561274/fonttools-4.43.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached fonttools-4.43.1-cp310-cp310-win_amd64.whl.metadata (155 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/4a/a1/8a9c9be45c642fa12954855d8b3a02d9fd8551165a558835a19508fec2e6/kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/23/ca/7296d769f62266c0f94bf76496bc77114e7a96d2de3d7bcba91d0ba2856f/Pillow-10.0.1-cp310-cp310-win_amd64.whl.metadata
#   Using cached Pillow-10.0.1-cp310-cp310-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r requirements.txt (line 7))
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (2.8.2)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers->-r requirements.txt (line 9))
#   Obtaining dependency information for huggingface-hub<1.0,>=0.16.4 from https://files.pythonhosted.org/packages/ef/b5/b6107bd65fa4c96fdf00e4733e2fe5729bb9e5e09997f63074bb43d3ab28/huggingface_hub-0.18.0-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.18.0-py3-none-any.whl.metadata (13 kB)
# Collecting regex!=2019.12.17 (from transformers->-r requirements.txt (line 9))
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/33/03/91c9509b43154795fb848a4cf8cef5b37302b3b3ccf8a9763046ea528c6b/regex-2023.10.3-cp310-cp310-win_amd64.whl.metadata
#   Using cached regex-2023.10.3-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.15,>=0.14 (from transformers->-r requirements.txt (line 9))
#   Obtaining dependency information for tokenizers<0.15,>=0.14 from https://files.pythonhosted.org/packages/92/02/15556b80450301d2ef014bc598df4352bfb39631c5fcff758d8e0ac9f065/tokenizers-0.14.1-cp310-none-win_amd64.whl.metadata
#   Using cached tokenizers-0.14.1-cp310-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 9))
#   Obtaining dependency information for safetensors>=0.3.1 from https://files.pythonhosted.org/packages/35/c0/d5c1ef78fd9d52913b70574501562c38916927f1778a6baf4f0b80129463/safetensors-0.4.0-cp310-none-win_amd64.whl.metadata
#   Using cached safetensors-0.4.0-cp310-none-win_amd64.whl.metadata (3.8 kB)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 10))
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas->-r requirements.txt (line 10))
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting joblib>=1.1.1 (from scikit-learn->-r requirements.txt (line 15))
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r requirements.txt (line 15))
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting smart-open>=1.8.1 (from gensim->-r requirements.txt (line 17))
#   Obtaining dependency information for smart-open>=1.8.1 from https://files.pythonhosted.org/packages/fc/d9/d97f1db64b09278aba64e8c81b5d322d436132df5741c518f3823824fae0/smart_open-6.4.0-py3-none-any.whl.metadata
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting click (from sacremoses~=0.0.35->-r requirements.txt (line 18))
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tornado in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from visdom~=0.1.8.9->-r requirements.txt (line 21)) (6.3.3)
# Requirement already satisfied: pyzmq in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from visdom~=0.1.8.9->-r requirements.txt (line 21)) (23.2.0)
# Collecting jsonpatch (from visdom~=0.1.8.9->-r requirements.txt (line 21))
#   Obtaining dependency information for jsonpatch from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting torchfile (from visdom~=0.1.8.9->-r requirements.txt (line 21))
#   Using cached torchfile-0.1.0-py3-none-any.whl
# Requirement already satisfied: websocket-client in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from visdom~=0.1.8.9->-r requirements.txt (line 21)) (0.58.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers->-r requirements.txt (line 9))
#   Obtaining dependency information for huggingface-hub<1.0,>=0.16.4 from https://files.pythonhosted.org/packages/aa/f3/3fc97336a0e90516901befd4f500f08d691034d387406fdbde85bea827cc/huggingface_hub-0.17.3-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from click->sacremoses~=0.0.35->-r requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from jinja2->torch->-r requirements.txt (line 3)) (2.1.1)
# Collecting jsonpointer>=1.9 (from jsonpatch->visdom~=0.1.8.9->-r requirements.txt (line 21))
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from portalocker->sacrebleu~=1.4.2->-r requirements.txt (line 6)) (305.1)
# Collecting charset-normalizer<4,>=2 (from requests->torchtext~=0.4.0->-r requirements.txt (line 2))
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/09/b8/cf771dcdfe62453b5e59b05b85ab261df1da60b1bc10c7f260b468c62426/charset_normalizer-3.3.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached charset_normalizer-3.3.0-cp310-cp310-win_amd64.whl.metadata (33 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from requests->torchtext~=0.4.0->-r requirements.txt (line 2)) (3.4)
# Collecting urllib3<3,>=1.21.1 (from requests->torchtext~=0.4.0->-r requirements.txt (line 2))
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/26/40/9957270221b6d3e9a3b92fdfba80dd5c9661ff45a664b47edd5d00f707f5/urllib3-2.0.6-py3-none-any.whl.metadata
#   Using cached urllib3-2.0.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->torchtext~=0.4.0->-r requirements.txt (line 2))
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting mpmath>=0.19 (from sympy->torch->-r requirements.txt (line 3))
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached torch-2.1.0-cp310-cp310-win_amd64.whl (192.3 MB)
# Using cached numpy-1.26.0-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached matplotlib-3.8.0-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached transformers-4.34.0-py3-none-any.whl (7.7 MB)
# Using cached pandas-2.1.1-cp310-cp310-win_amd64.whl (10.7 MB)
# Using cached scikit_learn-1.3.1-cp310-cp310-win_amd64.whl (9.3 MB)
# Using cached gensim-4.3.2-cp310-cp310-win_amd64.whl (24.0 MB)
# Using cached scipy-1.11.3-cp310-cp310-win_amd64.whl (44.1 MB)
# Using cached contourpy-1.1.1-cp310-cp310-win_amd64.whl (477 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.43.1-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached fsspec-2023.9.2-py3-none-any.whl (173 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached Pillow-10.0.1-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached regex-2023.10.3-cp310-cp310-win_amd64.whl (269 kB)
# Using cached safetensors-0.4.0-cp310-none-win_amd64.whl (277 kB)
# Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tokenizers-0.14.1-cp310-none-win_amd64.whl (2.2 MB)
# Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached filelock-3.12.4-py3-none-any.whl (11 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached charset_normalizer-3.3.0-cp310-cp310-win_amd64.whl (98 kB)
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached urllib3-2.0.6-py3-none-any.whl (123 kB)
# Installing collected packages: umap, typing, torchfile, sentencepiece, pytz, mpmath, glob2, urllib3, tzdata, tqdm, threadpoolctl, tabulate, sympy, smart-open, safetensors, regex, pyyaml, pyparsing, portalocker, pillow, numpy, networkx, kiwisolver, jsonpointer, joblib, fsspec, fonttools, filelock, cycler, click, charset-normalizer, certifi, torch, scipy, sacremoses, sacrebleu, requests, pandas, oyaml, jsonpatch, contourpy, visdom, torchtext, scikit-learn, matplotlib, huggingface-hub, gensim, tokenizers, seaborn, transformers
# Successfully installed certifi-2023.7.22 charset-normalizer-3.3.0 click-8.1.7 contourpy-1.1.1 cycler-0.12.1 filelock-3.12.4 fonttools-4.43.1 fsspec-2023.9.2 gensim-4.3.2 glob2-0.7 huggingface-hub-0.17.3 joblib-1.3.2 jsonpatch-1.33 jsonpointer-2.4 kiwisolver-1.4.5 matplotlib-3.8.0 mpmath-1.3.0 networkx-3.1 numpy-1.26.0 oyaml-0.9 pandas-2.1.1 pillow-10.0.1 portalocker-2.8.2 pyparsing-3.1.1 pytz-2023.3.post1 pyyaml-6.0.1 regex-2023.10.3 requests-2.31.0 sacrebleu-1.4.14 sacremoses-0.0.53 safetensors-0.4.0 scikit-learn-1.3.1 scipy-1.11.3 seaborn-0.9.1 sentencepiece-0.1.99 smart-open-6.4.0 sympy-1.12 tabulate-0.8.10 threadpoolctl-3.2.0 tokenizers-0.14.1 torch-2.1.0 torchfile-0.1.0 torchtext-0.4.0 tqdm-4.43.0 transformers-4.34.0 typing-3.6.6 tzdata-2023.3 umap-0.1.1 urllib3-2.0.6 visdom-0.1.8.9

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Obtaining dependency information for tensorboard from https://files.pythonhosted.org/packages/73/a2/66ed644f6ed1562e0285fcd959af17670ea313c8f331c46f79ee77187eb9/tensorboard-2.14.1-py3-none-any.whl.metadata
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/c7/40/d43d62a1da2d49700c3defddc307ca4b4e1a405a6ffd5fdacfcb4eea03da/grpcio-1.59.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading grpcio-1.59.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/39/7c/2e4fa55a99f83ef9ef229ac5d59c44ceb90e2d0145711590c0fa39669f32/google_auth-2.23.3-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/bb/c1/50caaec6cadc1c6adc8fe351e03bd646d6e4dd17f55fca0f4c8d7ea8d3e9/Markdown-3.5-py3-none-any.whl.metadata
#   Downloading Markdown-3.5-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from tensorboard) (1.26.0)
# Collecting protobuf>=3.19.6 (from tensorboard)
#   Obtaining dependency information for protobuf>=3.19.6 from https://files.pythonhosted.org/packages/c2/59/f89c04923d68595d359f4cd7adbbdf5e5d791257945f8873d88b2fd1f979/protobuf-4.24.4-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.24.4-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from tensorboard) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/b6/a5/54b01f663d60d5334f6c9c87c26274e94617a4fd463d812463626423b10d/werkzeug-3.0.0-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/5.5 MB 3.2 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/5.5 MB 3.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.7/5.5 MB 6.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.5/5.5 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.0/5.5 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 19.6 MB/s eta 0:00:00
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Downloading google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.3 kB ? eta -:--:--
#    ---------------------------------------- 182.3/182.3 kB ? eta 0:00:00
# Downloading grpcio-1.59.0-cp310-cp310-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.7 MB 22.0 MB/s eta 0:00:01
#    ------------------------- -------------- 2.4/3.7 MB 25.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.5/3.7 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 23.4 MB/s eta 0:00:00
# Downloading Markdown-3.5-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 101.7/101.7 kB 5.7 MB/s eta 0:00:00
# Downloading protobuf-4.24.4-cp310-abi3-win_amd64.whl (430 kB)
#    ---------------------------------------- 0.0/430.5 kB ? eta -:--:--
#    --------------------------------------- 430.5/430.5 kB 28.0 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.0-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.6 kB ? eta -:--:--
#    --------------------------------------- 226.6/226.6 kB 13.5 MB/s eta 0:00:00
# Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, pyasn1, protobuf, oauthlib, markdown, grpcio, cachetools, absl-py, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-2.0.0 cachetools-5.3.1 google-auth-2.23.3 google-auth-oauthlib-1.0.0 grpcio-1.59.0 markdown-3.5 oauthlib-3.2.2 protobuf-4.24.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.14.1 tensorboard-data-server-0.7.1 werkzeug-3.0.0

# %%
# !python models/sent_lm.py --config configs/prototype.trans_lm_qu.yaml
# Out:
# config:configs/prototype.trans_lm_qu.yaml
# name:prototype.trans_lm_qu
# desc:None
# tag:None
# visdom:False
# pin_memory:False
# resume_cp:None
# resume_state_id:None
# device:cpu
# cores:4
# src_dirs:['C:\\Users\\gabri\\Rimanakuy\\models', 'C:\\Users\\gabri\\Rimanakuy\\modules', 'C:\\Users\\gabri\\Rimanakuy\\helpers']
#
# {'batch_tokens': 1000,
#  'config': 'configs/prototype.trans_lm_qu.yaml',
#  'cores': 4,
#  'data': {'embeddings': None,
#           'seq_len': 250,
#           'sos': True,
#           'subword_path': 'C:\\Users\\gabri\\Rimanakuy\\datasets\\source',
#           'train_path': 'C:\\Users\\gabri\\Rimanakuy\\datasets\\mono\\prototype\\en.train',
#           'val_path': 'C:\\Users\\gabri\\Rimanakuy\\datasets\\mono\\prototype\\en.valid',
#           'vocab_size': 10000},
#  'desc': None,
#  'device': 'cpu',
#  'epochs': 200,
#  'logging': {'checkpoint_interval': 1000,
#              'emb_inspect_interval': 1000,
#              'log_interval': 100,
#              'module_grad_interval': 500,
#              'samples_interval': 500},
#  'losses': {'lm': {'perplexity': True, 'tag': 'lm', 'weight': 1}},
#  'model': {'dropout': 0.1,
#            'emb_size': 512,
#            'emb_trainable': True,
#            'inp_dropout': 0.0,
#            'mode': 'LM',
#            'nhead': 8,
#            'nhid': 1024,
#            'nlayers': 4,
#            'tie_projections': True,
#            'type': 'transformer'},
#  'name': 'prototype.trans_lm_qu',
#  'optim': {'clip': 1,
#            'early_stop': 10,
#            'eta_min': 1e-05,
#            'gamma': 0.3,
#            'k': 10,
#            'lr': 0.001,
#            'milestones': [5, 15],
#            'min_lr': 0.0001,
#            'optimizer': 'ranger',
#            'patience': 2,
#            'scheduler': 'plateau',
#            'step_size': 1,
#            'weight_decay': 0.0},
#  'parallel': False,
#  'pin_memory': False,
#  'resume_cp': None,
#  'resume_state_id': None,
#  'src_dirs': ['C:\\Users\\gabri\\Rimanakuy\\models',
#               'C:\\Users\\gabri\\Rimanakuy\\modules',
#               'C:\\Users\\gabri\\Rimanakuy\\helpers'],
#  'tag': None,
#  'visdom': False}
# Building training dataset...
# Preprocessing...
# Caching lines to C:\Users\gabri\Rimanakuy\datasets\mono\prototype\en.train.cache
# Writing data to cache...
# file        examples    vocab    tokens (unique)  tokens (total)      max length
# --------  ----------  -------  -----------------  ----------------  ------------
# en.train       10000    38218              38215  718.3K                     250
# Building validation dataset...
# Preprocessing...
# Caching lines to C:\Users\gabri\Rimanakuy\datasets\mono\prototype\en.valid.cache
# Writing data to cache...
# file        examples    vocab    tokens (unique)  tokens (total)      max length
# --------  ----------  -------  -----------------  ----------------  ------------
# en.valid        1000    38218              38215  74.0K                      250
# TransformerLM(
#   (embed): Embed(
#     (embedding): Embedding(38218, 512, padding_idx=0)
#     (emb_dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): TransformerEncoder(num_layers=4, num_heads=8)
#   (logits): Linear(in_features=512, out_features=38218, bias=True)
# )
# Total Params: 28.0M
# Total Trainable Params: 28.0M
# Starting with state id:None...
#   0%|          | 0/1512946 [00:00<?, ?it/s]
#  10%|9         | 147771/1512946 [00:00<00:00, 1471655.39it/s]
#  21%|##1       | 320740/1512946 [00:00<00:00, 1539067.38it/s]
#  32%|###2      | 490888/1512946 [00:00<00:00, 1584279.61it/s]
#  44%|####4     | 668555/1512946 [00:00<00:00, 1636901.18it/s]
#  56%|#####5    | 843211/1512946 [00:00<00:00, 1668085.21it/s]
#  68%|######7   | 1022063/1512946 [00:00<00:00, 1700951.58it/s]
#  79%|#######8  | 1194080/1512946 [00:00<00:00, 1701857.20it/s]
#  90%|######### | 1368780/1512946 [00:00<00:00, 1711997.88it/s]
# 100%|#########9| 1512817/1512946 [00:00<00:00, 1707446.50it/s]
#
#   0%|          | 0/153250 [00:00<?, ?it/s]
# 100%|#########9| 153097/153250 [00:00<00:00, 1527293.69it/s]
# Setting up a new session...
# Without the incoming socket you cannot receive events from the server or register event handlers to your Visdom client.
# Traceback (most recent call last):
#   File "C:\Users\gabri\Rimanakuy\models\sent_lm.py", line 105, in <module>
#     trained_model = run(_config)
#   File "C:\Users\gabri\Rimanakuy\models\sent_lm.py", line 87, in run
#     train_loss = trainer.train_epoch()
#   File "C:\Users\gabri\Rimanakuy\.\modules\trainer.py", line 454, in train_epoch
#     for batch_index, batch in enumerate(self.train_loader, 1):
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages\torch\utils\data\dataloader.py", line 438, in __iter__
#     return self._get_iterator()
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages\torch\utils\data\dataloader.py", line 386, in _get_iterator
#     return _MultiProcessingDataLoaderIter(self)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\site-packages\torch\utils\data\dataloader.py", line 1039, in __init__
#     w.start()
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\context.py", line 224, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\context.py", line 336, in _Popen
#     return Popen(process_obj)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\popen_spawn_win32.py", line 93, in __init__
#     reduction.dump(process_obj, to_child)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# AttributeError: Can't pickle local object 'BaseSequenceDataset.__init__.<locals>.<lambda>'
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\gabri\anaconda3\envs\rimanakuy1\lib\multiprocessing\spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# EOFError: Ran out of input

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %%
# !pip install dill
# Out:
# Collecting dill
#   Obtaining dependency information for dill from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/115.3 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/115.3 kB ? eta -:--:--
#    ------------- ------------------------- 41.0/115.3 kB 393.8 kB/s eta 0:00:01
#    ------------------------ -------------- 71.7/115.3 kB 563.7 kB/s eta 0:00:01
#    -------------------------------------- 115.3/115.3 kB 673.2 kB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.7

# %%
# !python models/nmt_prior.py --config configs/transformer/trans.ques_base.yaml --name final.trans.ques_base
# Out:
# ^C
